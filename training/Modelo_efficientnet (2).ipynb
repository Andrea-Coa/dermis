# %% [markdown]
# #EffiV1

# %%
import os
import zipfile
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
notebook_path = '/content/drive/Shared drives/Desarrollo/'

# %%
# !ls "{notebook_path}"
# Out:
#  _annotations.csv
# 'Baumann, Leslie - The Skin Type Solution_ a Revolutionary Guide to Your Best Skin Ever (2010, Random House Publishing Group) - libgen.li.pdf'
#  book-products
# 'Facial Skin.v1i.voc'
#  facial_skin.zip
# 'Fichas tecnicas'
#  files
# 'fotos de prueba'
#  Modelo_efficientnet.ipynb
#  Modelo_Unet.ipynb
#  models
#  README.dataset.txt
#  README.roboflow.txt
#  routines
#  scrape
#  scraped-products
#  skin_defects.csv
#  skin_deffects_angles.zip
#  Skin_deffects.ipynb
#  train
#  transformer
#  valid

# %%
#!pip install timm
import os
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
import timm
from sklearn.metrics import f1_score, accuracy_score

# %%
class SkinDataset(Dataset):
    def __init__(self, dataframe, image_dir, transform=None):
        self.dataframe = dataframe
        self.image_dir = image_dir
        self.transform = transform
        self.image_filenames = dataframe['filename'].values
        self.labels = dataframe.drop(columns=['filename', 'source']).values.astype('float32')

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_path = os.path.join(self.image_dir, self.image_filenames[idx])
        image = Image.open(img_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        label = torch.tensor(self.labels[idx])
        return image, label

# %%
notebook_path = '/content/drive/Shared drives/Desarrollo'
df = pd.read_csv(f"{notebook_path}/_annotations.csv")

df['filename'] = df['filename'].str.strip()  # Asegura que no hay espacios raros

df_train = df[df['source'] == 'train'].reset_index(drop=True)
df_test = df[df['source'] == 'test'].reset_index(drop=True)

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

train_dataset = SkinDataset(df_train, f"{notebook_path}/train", transform=transform)
test_dataset = SkinDataset(df_test, f"{notebook_path}/valid", transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=2)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

num_classes = df_train.drop(columns=['filename', 'source']).shape[1]

model = timm.create_model('tf_efficientnet_b0', pretrained=True, num_classes=num_classes)
model = model.to(device)

criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/21.4M [00:00<?, ?B/s]

# %%
def train_one_epoch(model, dataloader, optimizer, device):
    model.train()
    running_loss = 0
    for images, labels in dataloader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    return running_loss / len(dataloader)


def evaluate(model, dataloader, device):
    model.eval()
    all_labels = []
    all_preds = []
    running_loss = 0

    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)
            preds = torch.sigmoid(outputs).cpu().numpy()
            labels = labels.cpu().numpy()

            all_labels.extend(labels)
            all_preds.extend(preds)
            running_loss += loss.item()

    all_labels = np.array(all_labels)
    all_preds_bin = (np.array(all_preds) > 0.5).astype(int)

    f1 = f1_score(all_labels, all_preds_bin, average='macro')
    acc = accuracy_score(all_labels, all_preds_bin)
    return running_loss / len(dataloader), f1, acc

# %%
num_epochs = 10
for epoch in range(num_epochs):
    print(f"\nÉpoca {epoch+1}/{num_epochs}")
    train_loss = train_one_epoch(model, train_loader, optimizer, device)
    print(f"🔧 Train Loss: {train_loss:.4f}")
# Out:
# Época 1/10
# 🔧 Train Loss: 0.5323
#
# Época 2/10
# 🔧 Train Loss: 0.2416
#
# Época 3/10
# 🔧 Train Loss: 0.1677
#
# Época 4/10
# 🔧 Train Loss: 0.1372
#
# Época 5/10
# 🔧 Train Loss: 0.1126
#
# Época 6/10
# 🔧 Train Loss: 0.0871
#
# Época 7/10
# 🔧 Train Loss: 0.0735
#
# Época 8/10
# 🔧 Train Loss: 0.0602
#
# Época 9/10
# 🔧 Train Loss: 0.0504
#
# Época 10/10
# 🔧 Train Loss: 0.0387

# %%
from sklearn.metrics import classification_report, f1_score, accuracy_score, precision_score, recall_score, hamming_loss

def evaluate_with_metrics(model, dataloader, device, class_names=None):
    model.eval()
    all_labels = []
    all_preds = []

    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            probs = torch.sigmoid(outputs).cpu().numpy()
            labels = labels.cpu().numpy()
            all_preds.extend(probs)
            all_labels.extend(labels)

    all_preds_bin = (np.array(all_preds) > 0.5).astype(int)
    all_labels = np.array(all_labels)

    print("Classification Report (per class):")
    print(classification_report(all_labels, all_preds_bin, target_names=class_names, zero_division=0))

    print("\nOther multilabel metrics:")
    print(f"Subset accuracy: {accuracy_score(all_labels, all_preds_bin):.4f}")
    print(f"F1 macro: {f1_score(all_labels, all_preds_bin, average='macro'):.4f}")
    print(f"F1 micro: {f1_score(all_labels, all_preds_bin, average='micro'):.4f}")
    print(f"Precision macro: {precision_score(all_labels, all_preds_bin, average='macro'):.4f}")
    print(f"Recall macro: {recall_score(all_labels, all_preds_bin, average='macro'):.4f}")
    print(f"Hamming loss: {hamming_loss(all_labels, all_preds_bin):.4f}")

# %%
class_names = df_train.drop(columns=['filename', 'source']).columns.tolist()
evaluate_with_metrics(model, test_loader, device, class_names=class_names)
# Out:
# Classification Report (per class):
#               precision    recall  f1-score   support
#
#      eye_bag       0.00      0.00      0.00         2
#    acne_scar       0.07      1.00      0.13         1
#      freckle       0.93      0.93      0.93        15
#      nodules       0.40      0.33      0.36         6
#      papules       0.52      0.52      0.52        21
#     pustules       0.33      0.14      0.20         7
#  skinredness       0.00      0.00      0.00         7
#     vascular       0.00      0.00      0.00         3
#      wrinkle       0.90      1.00      0.95        18
#  dark_circle       1.00      0.56      0.72        16
#   black_head       0.82      0.74      0.78        19
#   white_head       0.79      0.62      0.70        24
#    dark_spot       0.00      0.00      0.00         0
#       stains       0.75      0.82      0.78        11
#
#    micro avg       0.69      0.63      0.66       150
#    macro avg       0.47      0.48      0.43       150
# weighted avg       0.70      0.63      0.65       150
#  samples avg       0.66      0.67      0.66       150
#
#
# Other multilabel metrics:
# Subset accuracy: 0.5050
# F1 macro: 0.4343
# F1 micro: 0.6551
# Precision macro: 0.4661
# Recall macro: 0.4768
# Hamming loss: 0.0700
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#print(model.state_dict())

# %%
import os
import torch
model_dir = '/content/drive/Shared drives/Desarrollo/models'

if not os.path.exists(model_dir):
    os.makedirs(model_dir)
    print(f"Created directory: {model_dir}")

torch.save(model.state_dict(), os.path.join(model_dir, 'efficientnet_v1.pth'))
# Out:
# Created directory: /content/drive/Shared drives/Desarrollo/models

# %% [markdown]
# # Prueba EffiV1

# %%
from torchvision import transforms
from PIL import Image
import torch

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# %%
image_path = '/content/drive/Shared drives/Desarrollo/fotos de prueba/papita.jpg'
image = Image.open(image_path).convert('RGB')


input_tensor = transform(image).unsqueeze(0).to(device)

# %%
model.eval()
with torch.no_grad():
    output = model(input_tensor)
    probs = torch.sigmoid(output).cpu().numpy()[0]

# %%
classes = df.drop(columns=['filename', 'source']).columns.tolist()

# %%
threshold = 0.5
predicted_labels = [cls for cls, prob in zip(classes, probs) if prob >= threshold]

print("Predicciones:", predicted_labels)
# Out:
# Predicciones: ['acne_scar', 'freckle', 'vascular', 'stains']

# %% [markdown]
# #Effi V2

# %%
from torchvision import transforms
import random

from torchvision import transforms

# Transformación normal (sin augmentation)
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# Transformación con augmentation
aug_transform = transforms.Compose([
    transforms.RandomResizedCrop(224, scale=(0.9, 1.0)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.1, hue=0.02),
    transforms.GaussianBlur(kernel_size=(3, 3), sigma=(0.1, 1.0)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# %%
class CustomMultiLabelDataset(Dataset):
    def __init__(self, df, image_dir, classes, transform=None, aug_transform=None, minority_classes=None):
        self.df = df.reset_index(drop=True)
        self.image_dir = image_dir
        self.transform = transform
        self.aug_transform = aug_transform
        self.classes = classes
        self.minority_classes = minority_classes or []

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        img_path = os.path.join(self.image_dir, row['filename'])
        image = Image.open(img_path).convert('RGB')

        labels = torch.tensor(row[self.classes].values.astype(np.float32))

        # Si tiene alguna clase minoritaria, aplicar augmentation
        if any(row[cls] == 1 for cls in self.minority_classes):
            if self.aug_transform:
                image = self.aug_transform(image)
        else:
            if self.transform:
                image = self.transform(image)

        return image, labels

    def __len__(self):
        return len(self.df)

# %%
minority_classes = [
    'eye_bag', 'dark_spot', 'vascular', 'skinredness',
    'pustules', 'dark_circle', 'nodules', 'freckle', 'stains'
]

# %%
from torch.utils.data import DataLoader

# Lista de columnas de clases (las etiquetas multilabel)
classes = [
    'papules', 'black_head', 'white_head', 'acne_scar', 'wrinkle', 'stains',
    'freckle', 'nodules', 'dark_circle', 'pustules', 'skinredness',
    'vascular', 'dark_spot', 'eye_bag'
]

# Dataset con augmentations aplicadas solo a clases minoritarias
train_dataset = CustomMultiLabelDataset(
    df=df_train,
    image_dir=f"{notebook_path}/train",
    classes=classes,
    transform=transform,
    aug_transform=aug_transform,
    minority_classes=minority_classes
)

# DataLoader
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# %%
num_epochs = 10
for epoch in range(num_epochs):
    print(f"\nÉpoca {epoch+1}/{num_epochs}")
    train_loss = train_one_epoch(model, train_loader, optimizer, device)
    print(f"🔧 Train Loss: {train_loss:.4f}")
# Out:
# Época 1/10
# 🔧 Train Loss: 0.4134
#
# Época 2/10
# 🔧 Train Loss: 0.1753
#
# Época 3/10
# 🔧 Train Loss: 0.1249
#
# Época 4/10
# 🔧 Train Loss: 0.1029
#
# Época 5/10
# 🔧 Train Loss: 0.0779
#
# Época 6/10
# 🔧 Train Loss: 0.0690
#
# Época 7/10
# 🔧 Train Loss: 0.0602
#
# Época 8/10
# 🔧 Train Loss: 0.0513
#
# Época 9/10
# 🔧 Train Loss: 0.0439
#
# Época 10/10
# 🔧 Train Loss: 0.0395

# %%
evaluate_with_metrics(model, test_loader, device, class_names=classes)
# Out:
# Classification Report (per class):
#               precision    recall  f1-score   support
#
#      papules       0.00      0.00      0.00         2
#   black_head       0.00      0.00      0.00         1
#   white_head       0.00      0.00      0.00        15
#    acne_scar       0.12      0.17      0.14         6
#      wrinkle       0.00      0.00      0.00        21
#       stains       0.06      0.14      0.09         7
#      freckle       0.11      0.29      0.16         7
#      nodules       0.00      0.00      0.00         3
#  dark_circle       0.10      0.06      0.07        18
#     pustules       0.00      0.00      0.00        16
#  skinredness       0.00      0.00      0.00        19
#     vascular       0.00      0.00      0.00        24
#    dark_spot       0.00      0.00      0.00         0
#      eye_bag       0.00      0.00      0.00        11
#
#    micro avg       0.07      0.03      0.05       150
#    macro avg       0.03      0.05      0.03       150
# weighted avg       0.03      0.03      0.03       150
#  samples avg       0.05      0.04      0.04       150
#
#
# Other multilabel metrics:
# Subset accuracy: 0.0297
# F1 macro: 0.0329
# F1 micro: 0.0457
# Precision macro: 0.0285
# Recall macro: 0.0465
# Hamming loss: 0.1478
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# # Logistic Multilabel

# %%
import torch
import torchvision.models as models
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.preprocessing import MultiLabelBinarizer
import numpy as np

# %%
classes = [
    'papules', 'black_head', 'white_head', 'acne_scar', 'wrinkle', 'stains',
    'freckle', 'nodules', 'dark_circle', 'pustules', 'skinredness',
    'vascular', 'dark_spot', 'eye_bag'
]

# %%
feature_extractor = models.efficientnet_b0(pretrained=True)
feature_extractor.classifier = torch.nn.Identity()
feature_extractor.eval().to(device)


simple_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

feature_dataset = CustomMultiLabelDataset(
    df=df_train,
    image_dir=f"{notebook_path}/train",
    classes=classes,
    transform=simple_transform,
    aug_transform=None,
    minority_classes=[]
)

feature_loader = DataLoader(feature_dataset, batch_size=32, shuffle=False)


features = []
targets = []

with torch.no_grad():
    for imgs, labels in feature_loader:
        imgs = imgs.to(device)
        feats = feature_extractor(imgs)
        features.append(feats.cpu().numpy())
        targets.append(labels.numpy())

X = np.vstack(features)
y = np.vstack(targets)


from sklearn.multioutput import MultiOutputClassifier

logistic = MultiOutputClassifier(LogisticRegression(max_iter=1000, class_weight='balanced'))
logistic.fit(X, y)
# Out:
# MultiOutputClassifier(estimator=LogisticRegression(class_weight='balanced',
#                                                    max_iter=1000))

# %%
test_dataset = CustomMultiLabelDataset(
    df=df_test,
    image_dir=f"{notebook_path}/valid",
    classes=classes,
    transform=simple_transform,
    aug_transform=None,
    minority_classes=[]
)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)


X_test = []
y_test = []

with torch.no_grad():
    for imgs, labels in test_loader:
        imgs = imgs.to(device)
        feats = feature_extractor(imgs)
        X_test.append(feats.cpu().numpy())
        y_test.append(labels.numpy())

X_test = np.vstack(X_test)
y_test = np.vstack(y_test)

# %%
y_pred = logistic.predict(X_test)

print(classification_report(y_test, y_pred, target_names=classes))
# Out:
#               precision    recall  f1-score   support
#
#      papules       0.58      0.67      0.62        21
#   black_head       0.71      0.79      0.75        19
#   white_head       0.62      0.54      0.58        24
#    acne_scar       0.06      1.00      0.12         1
#      wrinkle       0.86      1.00      0.92        18
#       stains       0.77      0.91      0.83        11
#      freckle       0.88      1.00      0.94        15
#      nodules       0.20      0.33      0.25         6
#  dark_circle       0.87      0.81      0.84        16
#     pustules       0.12      0.14      0.13         7
#  skinredness       0.60      0.86      0.71         7
#     vascular       0.40      0.67      0.50         3
#    dark_spot       0.00      0.00      0.00         0
#      eye_bag       0.00      0.00      0.00         2
#
#    micro avg       0.60      0.73      0.66       150
#    macro avg       0.48      0.62      0.51       150
# weighted avg       0.66      0.73      0.69       150
#  samples avg       0.70      0.82      0.74       150
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import hamming_loss
from sklearn.metrics import average_precision_score

subset_acc = accuracy_score(y_test, y_pred)
print(f"Subset Accuracy: {subset_acc:.4f}")

hamming = hamming_loss(y_test, y_pred)
print(f"Hamming Loss: {hamming:.4f}")

map = average_precision_score(y_test, y_pred)
print(f"MAP: {map:.4f}")
# Out:
# Subset Accuracy: 0.4950
# Hamming Loss: 0.0806
# MAP: 0.4111
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf = MultiOutputClassifier(RandomForestClassifier(
    n_estimators=100,
    class_weight='balanced',
    random_state=42,
    n_jobs=-1
))

rf.fit(X, y)
# Out:
# MultiOutputClassifier(estimator=RandomForestClassifier(class_weight='balanced',
#                                                        n_jobs=-1,
#                                                        random_state=42))

# %%
y_pred_rf = rf.predict(X_test)
print(classification_report(y_test, y_pred_rf, target_names=classes))
# Out:
#               precision    recall  f1-score   support
#
#      papules       0.60      0.29      0.39        21
#   black_head       0.83      0.53      0.65        19
#   white_head       0.60      0.12      0.21        24
#    acne_scar       0.25      1.00      0.40         1
#      wrinkle       0.94      0.89      0.91        18
#       stains       0.60      0.27      0.38        11
#      freckle       1.00      0.33      0.50        15
#      nodules       0.00      0.00      0.00         6
#  dark_circle       0.00      0.00      0.00        16
#     pustules       0.00      0.00      0.00         7
#  skinredness       0.00      0.00      0.00         7
#     vascular       0.00      0.00      0.00         3
#    dark_spot       0.00      0.00      0.00         0
#      eye_bag       0.00      0.00      0.00         2
#
#    micro avg       0.76      0.29      0.42       150
#    macro avg       0.34      0.25      0.24       150
# weighted avg       0.54      0.29      0.36       150
#  samples avg       0.35      0.32      0.32       150
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import hamming_loss
from sklearn.metrics import average_precision_score

subset_acc = accuracy_score(y_test, y_pred)
print(f"Subset Accuracy: {subset_acc:.4f}")

hamming = hamming_loss(y_test, y_pred)
print(f"Hamming Loss: {hamming:.4f}")

map = average_precision_score(y_test, y_pred)
print(f"MAP: {map:.4f}")
# Out:
# Subset Accuracy: 0.4950
# Hamming Loss: 0.0806
# MAP: 0.4111
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# %%
knn = KNeighborsClassifier()
multi_knn = MultiOutputClassifier(knn)

param_grid = {
    'estimator__n_neighbors': [3, 5, 7, 10]
}

grid_search = GridSearchCV(multi_knn, param_grid, cv=3, scoring='f1_micro', verbose=1)
grid_search.fit(X, y)

# Mejor modelo
best_knn = grid_search.best_estimator_
print("Mejor valor de n_neighbors:", grid_search.best_params_)
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# Mejor valor de n_neighbors: {'estimator__n_neighbors': 3}

# %%
y_pred = best_knn.predict(X_test)

print("Reporte de clasificación:")
print(classification_report(y_test, y_pred, target_names=classes))
# Out:
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#      papules       0.56      0.71      0.62        21
#   black_head       0.57      0.63      0.60        19
#   white_head       0.48      0.42      0.44        24
#    acne_scar       0.06      1.00      0.12         1
#      wrinkle       0.88      0.83      0.86        18
#       stains       0.80      0.73      0.76        11
#      freckle       0.83      0.67      0.74        15
#      nodules       0.00      0.00      0.00         6
#  dark_circle       1.00      0.38      0.55        16
#     pustules       0.14      0.14      0.14         7
#  skinredness       0.67      0.29      0.40         7
#     vascular       0.00      0.00      0.00         3
#    dark_spot       0.00      0.00      0.00         0
#      eye_bag       0.00      0.00      0.00         2
#
#    micro avg       0.56      0.53      0.54       150
#    macro avg       0.43      0.41      0.37       150
# weighted avg       0.62      0.53      0.55       150
#  samples avg       0.57      0.58      0.56       150
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import hamming_loss
from sklearn.metrics import average_precision_score

subset_acc = accuracy_score(y_test, y_pred)
print(f"Subset Accuracy: {subset_acc:.4f}")

hamming = hamming_loss(y_test, y_pred)
print(f"Hamming Loss: {hamming:.4f}")

map = average_precision_score(y_test, y_pred)
print(f"MAP: {map:.4f}")
# Out:
# Subset Accuracy: 0.4257
# Hamming Loss: 0.0948
# MAP: 0.2979
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(

# %% [markdown]
# #XGBOOST

# %%
import xgboost as xgb

xgb_clf = xgb.XGBClassifier(
    objective='binary:logistic',
    eval_metric='logloss',
    use_label_encoder=False,
    n_jobs=-1,
    verbosity=0
)


multi_xgb = MultiOutputClassifier(xgb_clf)
multi_xgb.fit(X, y)
y_pred = multi_xgb.predict(X_test)

print("Reporte de clasificación con XGBoost:")
print(classification_report(y_test, y_pred, target_names=classes))
# Out:
# Reporte de clasificación con XGBoost:
#               precision    recall  f1-score   support
#
#      papules       0.53      0.38      0.44        21
#   black_head       0.79      0.58      0.67        19
#   white_head       0.71      0.42      0.53        24
#    acne_scar       0.12      1.00      0.22         1
#      wrinkle       0.80      0.89      0.84        18
#       stains       1.00      0.45      0.62        11
#      freckle       0.83      0.67      0.74        15
#      nodules       0.50      0.17      0.25         6
#  dark_circle       1.00      0.31      0.48        16
#     pustules       0.00      0.00      0.00         7
#  skinredness       1.00      0.14      0.25         7
#     vascular       0.00      0.00      0.00         3
#    dark_spot       0.00      0.00      0.00         0
#      eye_bag       0.00      0.00      0.00         2
#
#    micro avg       0.70      0.45      0.55       150
#    macro avg       0.52      0.36      0.36       150
# weighted avg       0.72      0.45      0.53       150
#  samples avg       0.50      0.50      0.49       150
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import hamming_loss
from sklearn.metrics import average_precision_score

subset_acc = accuracy_score(y_test, y_pred)
print(f"Subset Accuracy: {subset_acc:.4f}")

hamming = hamming_loss(y_test, y_pred)
print(f"Hamming Loss: {hamming:.4f}")

map = average_precision_score(y_test, y_pred)
print(f"MAP: {map:.4f}")
# Out:
# Subset Accuracy: 0.3564
# Hamming Loss: 0.0785
# MAP: 0.2966
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(

# %%
import joblib

model_dir = '/content/drive/Shared drives/Desarrollo/models'

# %%
joblib.dump(logistic, f"{model_dir}/logistic_regression_v1.pkl")
joblib.dump(rf, f"{model_dir}/random_forest_v1.pkl")
joblib.dump(best_knn, f"{model_dir}/knn_v1.pkl")
joblib.dump(multi_xgb, f"{model_dir}/xgboost_v1.pkl")
# Out:
# ['/content/drive/Shared drives/Desarrollo/models/xgboost_v1.pkl']

# %%
import os
os.makedirs(model_dir, exist_ok=True)

# %% [markdown]
# # MLP

# %%
from sklearn.neural_network import MLPClassifier

mlp_base = MLPClassifier(
    hidden_layer_sizes=(100, 50),
    max_iter=300,
    random_state=42,
    verbose=True
)

mlp_clf = MultiOutputClassifier(mlp_base)


mlp_clf.fit(X, y)
y_pred = mlp_clf.predict(X_test)


print(classification_report(y_test, y_pred, target_names=classes, zero_division=0))

f1_macro = f1_score(y_test, y_pred, average='macro')
# Out:
# Iteration 1, loss = 0.67667764
# Iteration 2, loss = 0.44497227
# Iteration 3, loss = 0.37584669
# Iteration 4, loss = 0.33425130
# Iteration 5, loss = 0.30920942
# Iteration 6, loss = 0.28979642
# Iteration 7, loss = 0.27258615
# Iteration 8, loss = 0.25205914
# Iteration 9, loss = 0.24598701
# Iteration 10, loss = 0.23138318
# Iteration 11, loss = 0.21390178
# Iteration 12, loss = 0.20408984
# Iteration 13, loss = 0.18953629
# Iteration 14, loss = 0.17880464
# Iteration 15, loss = 0.16805769
# Iteration 16, loss = 0.15810435
# Iteration 17, loss = 0.14604168
# Iteration 18, loss = 0.14655601
# Iteration 19, loss = 0.13015259
# Iteration 20, loss = 0.11972759
# Iteration 21, loss = 0.11278869
# Iteration 22, loss = 0.10217561
# Iteration 23, loss = 0.09405451
# Iteration 24, loss = 0.08819566
# Iteration 25, loss = 0.08895190
# Iteration 26, loss = 0.07249098
# Iteration 27, loss = 0.06671567
# Iteration 28, loss = 0.06542207
# Iteration 29, loss = 0.06076472
# Iteration 30, loss = 0.05217943
# Iteration 31, loss = 0.04824385
# Iteration 32, loss = 0.04060407
# Iteration 33, loss = 0.04150181
# Iteration 34, loss = 0.03853110
# Iteration 35, loss = 0.03550136
# Iteration 36, loss = 0.03087606
# Iteration 37, loss = 0.02583645
# Iteration 38, loss = 0.02574331
# Iteration 39, loss = 0.02228961
# Iteration 40, loss = 0.01884903
# Iteration 41, loss = 0.01843118
# Iteration 42, loss = 0.01593729
# Iteration 43, loss = 0.01493530
# Iteration 44, loss = 0.01339165
# Iteration 45, loss = 0.01227342
# Iteration 46, loss = 0.01169196
# Iteration 47, loss = 0.01075354
# Iteration 48, loss = 0.00997660
# Iteration 49, loss = 0.00922100
# Iteration 50, loss = 0.00834381
# Iteration 51, loss = 0.00825972
# Iteration 52, loss = 0.00749002
# Iteration 53, loss = 0.00693562
# Iteration 54, loss = 0.00704679
# Iteration 55, loss = 0.00598708
# Iteration 56, loss = 0.00706701
# Iteration 57, loss = 0.00650065
# Iteration 58, loss = 0.00607843
# Iteration 59, loss = 0.00604296
# Iteration 60, loss = 0.00549620
# Iteration 61, loss = 0.00548869
# Iteration 62, loss = 0.00559527
# Iteration 63, loss = 0.00503444
# Iteration 64, loss = 0.00380501
# Iteration 65, loss = 0.00364554
# Iteration 66, loss = 0.00362587
# Iteration 67, loss = 0.00297820
# Iteration 68, loss = 0.00271806
# Iteration 69, loss = 0.00284983
# Iteration 70, loss = 0.00290681
# Iteration 71, loss = 0.00247421
# Iteration 72, loss = 0.00269846
# Iteration 73, loss = 0.00260362
# Iteration 74, loss = 0.00242643
# Iteration 75, loss = 0.00217018
# Iteration 76, loss = 0.00229052
# Iteration 77, loss = 0.00237883
# Iteration 78, loss = 0.00195535
# Iteration 79, loss = 0.00197082
# Iteration 80, loss = 0.00174171
# Iteration 81, loss = 0.00210265
# Iteration 82, loss = 0.00165153
# Iteration 83, loss = 0.00172205
# Iteration 84, loss = 0.00145020
# Iteration 85, loss = 0.00154290
# Iteration 86, loss = 0.00137789
# Iteration 87, loss = 0.00133464
# Iteration 88, loss = 0.00137050
# Iteration 89, loss = 0.00125727
# Iteration 90, loss = 0.00127760
# Iteration 91, loss = 0.00123377
# Iteration 92, loss = 0.00112985
# Iteration 93, loss = 0.00112015
# Iteration 94, loss = 0.00108602
# Iteration 95, loss = 0.00110869
# Iteration 96, loss = 0.00113321
# Iteration 97, loss = 0.00102198
# Iteration 98, loss = 0.00105528
# Iteration 99, loss = 0.00104818
# Iteration 100, loss = 0.00094668
# Iteration 101, loss = 0.00097696
# Iteration 102, loss = 0.00089683
# Iteration 103, loss = 0.00087159
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.68902685
# Iteration 2, loss = 0.44557003
# Iteration 3, loss = 0.38546917
# Iteration 4, loss = 0.34860352
# Iteration 5, loss = 0.32906543
# Iteration 6, loss = 0.30642065
# Iteration 7, loss = 0.29119400
# Iteration 8, loss = 0.27612303
# Iteration 9, loss = 0.26358671
# Iteration 10, loss = 0.25344513
# Iteration 11, loss = 0.24317891
# Iteration 12, loss = 0.22791927
# Iteration 13, loss = 0.21918445
# Iteration 14, loss = 0.20638370
# Iteration 15, loss = 0.19589252
# Iteration 16, loss = 0.18462105
# Iteration 17, loss = 0.17362169
# Iteration 18, loss = 0.16174521
# Iteration 19, loss = 0.16471886
# Iteration 20, loss = 0.15452963
# Iteration 21, loss = 0.13223128
# Iteration 22, loss = 0.12610420
# Iteration 23, loss = 0.11643278
# Iteration 24, loss = 0.11055212
# Iteration 25, loss = 0.10472935
# Iteration 26, loss = 0.10393386
# Iteration 27, loss = 0.08788387
# Iteration 28, loss = 0.08094200
# Iteration 29, loss = 0.07341893
# Iteration 30, loss = 0.06445153
# Iteration 31, loss = 0.06457679
# Iteration 32, loss = 0.05692332
# Iteration 33, loss = 0.05223838
# Iteration 34, loss = 0.05099764
# Iteration 35, loss = 0.04841004
# Iteration 36, loss = 0.04942829
# Iteration 37, loss = 0.04033896
# Iteration 38, loss = 0.03802059
# Iteration 39, loss = 0.03555522
# Iteration 40, loss = 0.03855327
# Iteration 41, loss = 0.03022742
# Iteration 42, loss = 0.02753832
# Iteration 43, loss = 0.02437448
# Iteration 44, loss = 0.02221945
# Iteration 45, loss = 0.02169090
# Iteration 46, loss = 0.01953446
# Iteration 47, loss = 0.01817011
# Iteration 48, loss = 0.01819651
# Iteration 49, loss = 0.01558727
# Iteration 50, loss = 0.01477864
# Iteration 51, loss = 0.01472923
# Iteration 52, loss = 0.01242835
# Iteration 53, loss = 0.01160039
# Iteration 54, loss = 0.01132848
# Iteration 55, loss = 0.01001490
# Iteration 56, loss = 0.00952629
# Iteration 57, loss = 0.00922008
# Iteration 58, loss = 0.00873951
# Iteration 59, loss = 0.00808369
# Iteration 60, loss = 0.00774450
# Iteration 61, loss = 0.00732982
# Iteration 62, loss = 0.00749208
# Iteration 63, loss = 0.00828219
# Iteration 64, loss = 0.00701582
# Iteration 65, loss = 0.00661525
# Iteration 66, loss = 0.00590202
# Iteration 67, loss = 0.00553703
# Iteration 68, loss = 0.00499766
# Iteration 69, loss = 0.00477710
# Iteration 70, loss = 0.00490486
# Iteration 71, loss = 0.00488006
# Iteration 72, loss = 0.00428912
# Iteration 73, loss = 0.00387173
# Iteration 74, loss = 0.00376363
# Iteration 75, loss = 0.00374759
# Iteration 76, loss = 0.00344210
# Iteration 77, loss = 0.00328265
# Iteration 78, loss = 0.00303154
# Iteration 79, loss = 0.00302330
# Iteration 80, loss = 0.00287173
# Iteration 81, loss = 0.00277901
# Iteration 82, loss = 0.00267582
# Iteration 83, loss = 0.00268696
# Iteration 84, loss = 0.00251813
# Iteration 85, loss = 0.00238207
# Iteration 86, loss = 0.00242740
# Iteration 87, loss = 0.00230469
# Iteration 88, loss = 0.00221183
# Iteration 89, loss = 0.00214558
# Iteration 90, loss = 0.00205343
# Iteration 91, loss = 0.00196358
# Iteration 92, loss = 0.00190305
# Iteration 93, loss = 0.00186423
# Iteration 94, loss = 0.00178372
# Iteration 95, loss = 0.00175899
# Iteration 96, loss = 0.00170495
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.65076938
# Iteration 2, loss = 0.44121898
# Iteration 3, loss = 0.35428907
# Iteration 4, loss = 0.32389883
# Iteration 5, loss = 0.29906513
# Iteration 6, loss = 0.27964514
# Iteration 7, loss = 0.26941320
# Iteration 8, loss = 0.25723933
# Iteration 9, loss = 0.24527811
# Iteration 10, loss = 0.23505162
# Iteration 11, loss = 0.22806466
# Iteration 12, loss = 0.21733322
# Iteration 13, loss = 0.20722573
# Iteration 14, loss = 0.19618274
# Iteration 15, loss = 0.18523105
# Iteration 16, loss = 0.17754744
# Iteration 17, loss = 0.16659716
# Iteration 18, loss = 0.15619118
# Iteration 19, loss = 0.14847520
# Iteration 20, loss = 0.14707030
# Iteration 21, loss = 0.15028248
# Iteration 22, loss = 0.16054332
# Iteration 23, loss = 0.15275217
# Iteration 24, loss = 0.13512608
# Iteration 25, loss = 0.12197631
# Iteration 26, loss = 0.11575972
# Iteration 27, loss = 0.11068516
# Iteration 28, loss = 0.10246356
# Iteration 29, loss = 0.09018514
# Iteration 30, loss = 0.08436302
# Iteration 31, loss = 0.07952848
# Iteration 32, loss = 0.07566722
# Iteration 33, loss = 0.06879365
# Iteration 34, loss = 0.06654457
# Iteration 35, loss = 0.06196845
# Iteration 36, loss = 0.05444298
# Iteration 37, loss = 0.04945771
# Iteration 38, loss = 0.04577894
# Iteration 39, loss = 0.04534463
# Iteration 40, loss = 0.04409055
# Iteration 41, loss = 0.04605199
# Iteration 42, loss = 0.03633647
# Iteration 43, loss = 0.03396222
# Iteration 44, loss = 0.03067995
# Iteration 45, loss = 0.02806628
# Iteration 46, loss = 0.02597123
# Iteration 47, loss = 0.02316287
# Iteration 48, loss = 0.02266886
# Iteration 49, loss = 0.01839043
# Iteration 50, loss = 0.01716232
# Iteration 51, loss = 0.01778413
# Iteration 52, loss = 0.01600765
# Iteration 53, loss = 0.01363536
# Iteration 54, loss = 0.01224015
# Iteration 55, loss = 0.01219471
# Iteration 56, loss = 0.01077886
# Iteration 57, loss = 0.00958640
# Iteration 58, loss = 0.00977619
# Iteration 59, loss = 0.00854697
# Iteration 60, loss = 0.00787219
# Iteration 61, loss = 0.00728481
# Iteration 62, loss = 0.00686251
# Iteration 63, loss = 0.00631239
# Iteration 64, loss = 0.00608084
# Iteration 65, loss = 0.00591793
# Iteration 66, loss = 0.00547847
# Iteration 67, loss = 0.00536695
# Iteration 68, loss = 0.00535258
# Iteration 69, loss = 0.00509498
# Iteration 70, loss = 0.00446142
# Iteration 71, loss = 0.00442342
# Iteration 72, loss = 0.00395831
# Iteration 73, loss = 0.00380457
# Iteration 74, loss = 0.00381303
# Iteration 75, loss = 0.00352516
# Iteration 76, loss = 0.00336117
# Iteration 77, loss = 0.00341556
# Iteration 78, loss = 0.00316096
# Iteration 79, loss = 0.00292674
# Iteration 80, loss = 0.00292115
# Iteration 81, loss = 0.00277588
# Iteration 82, loss = 0.00265947
# Iteration 83, loss = 0.00262589
# Iteration 84, loss = 0.00260189
# Iteration 85, loss = 0.00244009
# Iteration 86, loss = 0.00222004
# Iteration 87, loss = 0.00225057
# Iteration 88, loss = 0.00217620
# Iteration 89, loss = 0.00210018
# Iteration 90, loss = 0.00195312
# Iteration 91, loss = 0.00194432
# Iteration 92, loss = 0.00187006
# Iteration 93, loss = 0.00174681
# Iteration 94, loss = 0.00177624
# Iteration 95, loss = 0.00173426
# Iteration 96, loss = 0.00166679
# Iteration 97, loss = 0.00156276
# Iteration 98, loss = 0.00157835
# Iteration 99, loss = 0.00153216
# Iteration 100, loss = 0.00150444
# Iteration 101, loss = 0.00139582
# Iteration 102, loss = 0.00141019
# Iteration 103, loss = 0.00143331
# Iteration 104, loss = 0.00131701
# Iteration 105, loss = 0.00129499
# Iteration 106, loss = 0.00124251
# Iteration 107, loss = 0.00121894
# Iteration 108, loss = 0.00117720
# Iteration 109, loss = 0.00115578
# Iteration 110, loss = 0.00112888
# Iteration 111, loss = 0.00109756
# Iteration 112, loss = 0.00107940
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.67930555
# Iteration 2, loss = 0.44164697
# Iteration 3, loss = 0.37617453
# Iteration 4, loss = 0.34972624
# Iteration 5, loss = 0.32949286
# Iteration 6, loss = 0.31142447
# Iteration 7, loss = 0.29952933
# Iteration 8, loss = 0.28688864
# Iteration 9, loss = 0.27949152
# Iteration 10, loss = 0.26855818
# Iteration 11, loss = 0.26303210
# Iteration 12, loss = 0.24642107
# Iteration 13, loss = 0.24145079
# Iteration 14, loss = 0.22888772
# Iteration 15, loss = 0.22112050
# Iteration 16, loss = 0.21640240
# Iteration 17, loss = 0.20358577
# Iteration 18, loss = 0.19248669
# Iteration 19, loss = 0.18289120
# Iteration 20, loss = 0.17091206
# Iteration 21, loss = 0.16113117
# Iteration 22, loss = 0.14897960
# Iteration 23, loss = 0.14587908
# Iteration 24, loss = 0.13610169
# Iteration 25, loss = 0.13020804
# Iteration 26, loss = 0.11911544
# Iteration 27, loss = 0.10743696
# Iteration 28, loss = 0.10121234
# Iteration 29, loss = 0.09627998
# Iteration 30, loss = 0.08215925
# Iteration 31, loss = 0.07604317
# Iteration 32, loss = 0.06574743
# Iteration 33, loss = 0.06012341
# Iteration 34, loss = 0.05778774
# Iteration 35, loss = 0.05604784
# Iteration 36, loss = 0.04792283
# Iteration 37, loss = 0.04610876
# Iteration 38, loss = 0.03747390
# Iteration 39, loss = 0.03345416
# Iteration 40, loss = 0.02865694
# Iteration 41, loss = 0.02592546
# Iteration 42, loss = 0.02419362
# Iteration 43, loss = 0.02140461
# Iteration 44, loss = 0.02036251
# Iteration 45, loss = 0.01863774
# Iteration 46, loss = 0.01858569
# Iteration 47, loss = 0.01702035
# Iteration 48, loss = 0.01493461
# Iteration 49, loss = 0.01309099
# Iteration 50, loss = 0.01282844
# Iteration 51, loss = 0.01119345
# Iteration 52, loss = 0.01014449
# Iteration 53, loss = 0.00922354
# Iteration 54, loss = 0.00868589
# Iteration 55, loss = 0.00819186
# Iteration 56, loss = 0.00774130
# Iteration 57, loss = 0.00710360
# Iteration 58, loss = 0.00653641
# Iteration 59, loss = 0.00618238
# Iteration 60, loss = 0.00560186
# Iteration 61, loss = 0.00530072
# Iteration 62, loss = 0.00500672
# Iteration 63, loss = 0.00471140
# Iteration 64, loss = 0.00453995
# Iteration 65, loss = 0.00447415
# Iteration 66, loss = 0.00403824
# Iteration 67, loss = 0.00383106
# Iteration 68, loss = 0.00364631
# Iteration 69, loss = 0.00346064
# Iteration 70, loss = 0.00334921
# Iteration 71, loss = 0.00315356
# Iteration 72, loss = 0.00300545
# Iteration 73, loss = 0.00290790
# Iteration 74, loss = 0.00281575
# Iteration 75, loss = 0.00271062
# Iteration 76, loss = 0.00256625
# Iteration 77, loss = 0.00245500
# Iteration 78, loss = 0.00237630
# Iteration 79, loss = 0.00231252
# Iteration 80, loss = 0.00219818
# Iteration 81, loss = 0.00218036
# Iteration 82, loss = 0.00200759
# Iteration 83, loss = 0.00197814
# Iteration 84, loss = 0.00191556
# Iteration 85, loss = 0.00179861
# Iteration 86, loss = 0.00192237
# Iteration 87, loss = 0.00173673
# Iteration 88, loss = 0.00173550
# Iteration 89, loss = 0.00164970
# Iteration 90, loss = 0.00160793
# Iteration 91, loss = 0.00152129
# Iteration 92, loss = 0.00145173
# Iteration 93, loss = 0.00143798
# Iteration 94, loss = 0.00137490
# Iteration 95, loss = 0.00140858
# Iteration 96, loss = 0.00135712
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.61557275
# Iteration 2, loss = 0.24550918
# Iteration 3, loss = 0.15128483
# Iteration 4, loss = 0.12977171
# Iteration 5, loss = 0.10434254
# Iteration 6, loss = 0.08197970
# Iteration 7, loss = 0.06705918
# Iteration 8, loss = 0.05103562
# Iteration 9, loss = 0.04273701
# Iteration 10, loss = 0.03305492
# Iteration 11, loss = 0.02836402
# Iteration 12, loss = 0.02287546
# Iteration 13, loss = 0.01858933
# Iteration 14, loss = 0.01478627
# Iteration 15, loss = 0.01169702
# Iteration 16, loss = 0.00967986
# Iteration 17, loss = 0.00763234
# Iteration 18, loss = 0.00614769
# Iteration 19, loss = 0.00501260
# Iteration 20, loss = 0.00421371
# Iteration 21, loss = 0.00345982
# Iteration 22, loss = 0.00289316
# Iteration 23, loss = 0.00247482
# Iteration 24, loss = 0.00213198
# Iteration 25, loss = 0.00188610
# Iteration 26, loss = 0.00165076
# Iteration 27, loss = 0.00146116
# Iteration 28, loss = 0.00131884
# Iteration 29, loss = 0.00118745
# Iteration 30, loss = 0.00108786
# Iteration 31, loss = 0.00100899
# Iteration 32, loss = 0.00091551
# Iteration 33, loss = 0.00083704
# Iteration 34, loss = 0.00077798
# Iteration 35, loss = 0.00073648
# Iteration 36, loss = 0.00068129
# Iteration 37, loss = 0.00064386
# Iteration 38, loss = 0.00061129
# Iteration 39, loss = 0.00057963
# Iteration 40, loss = 0.00054723
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.62209585
# Iteration 2, loss = 0.22529374
# Iteration 3, loss = 0.16396428
# Iteration 4, loss = 0.13672828
# Iteration 5, loss = 0.11486527
# Iteration 6, loss = 0.10411042
# Iteration 7, loss = 0.08855975
# Iteration 8, loss = 0.07671090
# Iteration 9, loss = 0.06597482
# Iteration 10, loss = 0.05745453
# Iteration 11, loss = 0.04882010
# Iteration 12, loss = 0.04264773
# Iteration 13, loss = 0.03716205
# Iteration 14, loss = 0.02979640
# Iteration 15, loss = 0.02576710
# Iteration 16, loss = 0.02122009
# Iteration 17, loss = 0.01835047
# Iteration 18, loss = 0.01517613
# Iteration 19, loss = 0.01280163
# Iteration 20, loss = 0.01114896
# Iteration 21, loss = 0.00917276
# Iteration 22, loss = 0.00760157
# Iteration 23, loss = 0.00671540
# Iteration 24, loss = 0.00566808
# Iteration 25, loss = 0.00494932
# Iteration 26, loss = 0.00437450
# Iteration 27, loss = 0.00399299
# Iteration 28, loss = 0.00410434
# Iteration 29, loss = 0.00332408
# Iteration 30, loss = 0.00287113
# Iteration 31, loss = 0.00246805
# Iteration 32, loss = 0.00224423
# Iteration 33, loss = 0.00199855
# Iteration 34, loss = 0.00188658
# Iteration 35, loss = 0.00161600
# Iteration 36, loss = 0.00154032
# Iteration 37, loss = 0.00143527
# Iteration 38, loss = 0.00131147
# Iteration 39, loss = 0.00122644
# Iteration 40, loss = 0.00114256
# Iteration 41, loss = 0.00111239
# Iteration 42, loss = 0.00102921
# Iteration 43, loss = 0.00097131
# Iteration 44, loss = 0.00091280
# Iteration 45, loss = 0.00086432
# Iteration 46, loss = 0.00082891
# Iteration 47, loss = 0.00078875
# Iteration 48, loss = 0.00075116
# Iteration 49, loss = 0.00072237
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.63664993
# Iteration 2, loss = 0.29804139
# Iteration 3, loss = 0.22004274
# Iteration 4, loss = 0.16595536
# Iteration 5, loss = 0.14125235
# Iteration 6, loss = 0.11548430
# Iteration 7, loss = 0.10317703
# Iteration 8, loss = 0.08761192
# Iteration 9, loss = 0.07499149
# Iteration 10, loss = 0.06202874
# Iteration 11, loss = 0.05180573
# Iteration 12, loss = 0.04382354
# Iteration 13, loss = 0.03549480
# Iteration 14, loss = 0.03004887
# Iteration 15, loss = 0.02745761
# Iteration 16, loss = 0.02375653
# Iteration 17, loss = 0.01766165
# Iteration 18, loss = 0.01485783
# Iteration 19, loss = 0.01351960
# Iteration 20, loss = 0.01016429
# Iteration 21, loss = 0.00928251
# Iteration 22, loss = 0.00743164
# Iteration 23, loss = 0.00655430
# Iteration 24, loss = 0.00566864
# Iteration 25, loss = 0.00493507
# Iteration 26, loss = 0.00437359
# Iteration 27, loss = 0.00394972
# Iteration 28, loss = 0.00347094
# Iteration 29, loss = 0.00317289
# Iteration 30, loss = 0.00281875
# Iteration 31, loss = 0.00259880
# Iteration 32, loss = 0.00226864
# Iteration 33, loss = 0.00210060
# Iteration 34, loss = 0.00190307
# Iteration 35, loss = 0.00176126
# Iteration 36, loss = 0.00165853
# Iteration 37, loss = 0.00149853
# Iteration 38, loss = 0.00148300
# Iteration 39, loss = 0.00131455
# Iteration 40, loss = 0.00124791
# Iteration 41, loss = 0.00116514
# Iteration 42, loss = 0.00109307
# Iteration 43, loss = 0.00102194
# Iteration 44, loss = 0.00096397
# Iteration 45, loss = 0.00090874
# Iteration 46, loss = 0.00086000
# Iteration 47, loss = 0.00082864
# Iteration 48, loss = 0.00077998
# Iteration 49, loss = 0.00074472
# Iteration 50, loss = 0.00071872
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.65731719
# Iteration 2, loss = 0.35362223
# Iteration 3, loss = 0.29899251
# Iteration 4, loss = 0.27360913
# Iteration 5, loss = 0.26043331
# Iteration 6, loss = 0.24633750
# Iteration 7, loss = 0.23415345
# Iteration 8, loss = 0.22516842
# Iteration 9, loss = 0.21459846
# Iteration 10, loss = 0.20751030
# Iteration 11, loss = 0.19646457
# Iteration 12, loss = 0.18866379
# Iteration 13, loss = 0.17973291
# Iteration 14, loss = 0.17235438
# Iteration 15, loss = 0.16672754
# Iteration 16, loss = 0.15665221
# Iteration 17, loss = 0.14979842
# Iteration 18, loss = 0.13581779
# Iteration 19, loss = 0.12791284
# Iteration 20, loss = 0.12474609
# Iteration 21, loss = 0.12011001
# Iteration 22, loss = 0.11006168
# Iteration 23, loss = 0.09577614
# Iteration 24, loss = 0.09570876
# Iteration 25, loss = 0.09130519
# Iteration 26, loss = 0.07339374
# Iteration 27, loss = 0.06668052
# Iteration 28, loss = 0.05946787
# Iteration 29, loss = 0.05482846
# Iteration 30, loss = 0.04756266
# Iteration 31, loss = 0.04372619
# Iteration 32, loss = 0.04545403
# Iteration 33, loss = 0.03619168
# Iteration 34, loss = 0.03447292
# Iteration 35, loss = 0.03022509
# Iteration 36, loss = 0.02562530
# Iteration 37, loss = 0.02282598
# Iteration 38, loss = 0.02215979
# Iteration 39, loss = 0.01897516
# Iteration 40, loss = 0.01733840
# Iteration 41, loss = 0.02060622
# Iteration 42, loss = 0.01457590
# Iteration 43, loss = 0.01451307
# Iteration 44, loss = 0.01325114
# Iteration 45, loss = 0.01181278
# Iteration 46, loss = 0.01088488
# Iteration 47, loss = 0.00964572
# Iteration 48, loss = 0.00881226
# Iteration 49, loss = 0.00835073
# Iteration 50, loss = 0.00785344
# Iteration 51, loss = 0.00713415
# Iteration 52, loss = 0.00660310
# Iteration 53, loss = 0.00631756
# Iteration 54, loss = 0.00604668
# Iteration 55, loss = 0.00558351
# Iteration 56, loss = 0.00529103
# Iteration 57, loss = 0.00511995
# Iteration 58, loss = 0.00485840
# Iteration 59, loss = 0.00438507
# Iteration 60, loss = 0.00430999
# Iteration 61, loss = 0.00397472
# Iteration 62, loss = 0.00373517
# Iteration 63, loss = 0.00357300
# Iteration 64, loss = 0.00346011
# Iteration 65, loss = 0.00347081
# Iteration 66, loss = 0.00306997
# Iteration 67, loss = 0.00314105
# Iteration 68, loss = 0.00304506
# Iteration 69, loss = 0.00274417
# Iteration 70, loss = 0.00267278
# Iteration 71, loss = 0.00264302
# Iteration 72, loss = 0.00256108
# Iteration 73, loss = 0.00238091
# Iteration 74, loss = 0.00233694
# Iteration 75, loss = 0.00224579
# Iteration 76, loss = 0.00216661
# Iteration 77, loss = 0.00225420
# Iteration 78, loss = 0.00206152
# Iteration 79, loss = 0.00199921
# Iteration 80, loss = 0.00206931
# Iteration 81, loss = 0.00199483
# Iteration 82, loss = 0.00190123
# Iteration 83, loss = 0.00167869
# Iteration 84, loss = 0.00167692
# Iteration 85, loss = 0.00167580
# Iteration 86, loss = 0.00157887
# Iteration 87, loss = 0.00160952
# Iteration 88, loss = 0.00155275
# Iteration 89, loss = 0.00144091
# Iteration 90, loss = 0.00136086
# Iteration 91, loss = 0.00143030
# Iteration 92, loss = 0.00129402
# Iteration 93, loss = 0.00129550
# Iteration 94, loss = 0.00122168
# Iteration 95, loss = 0.00118171
# Iteration 96, loss = 0.00120615
# Iteration 97, loss = 0.00128495
# Iteration 98, loss = 0.00117112
# Iteration 99, loss = 0.00123260
# Iteration 100, loss = 0.00113877
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.63501023
# Iteration 2, loss = 0.31487161
# Iteration 3, loss = 0.26653331
# Iteration 4, loss = 0.20952747
# Iteration 5, loss = 0.19554843
# Iteration 6, loss = 0.15738712
# Iteration 7, loss = 0.13318339
# Iteration 8, loss = 0.11166534
# Iteration 9, loss = 0.09396008
# Iteration 10, loss = 0.08168063
# Iteration 11, loss = 0.07095393
# Iteration 12, loss = 0.05662349
# Iteration 13, loss = 0.04664741
# Iteration 14, loss = 0.03918917
# Iteration 15, loss = 0.03320275
# Iteration 16, loss = 0.02674388
# Iteration 17, loss = 0.02276489
# Iteration 18, loss = 0.01760515
# Iteration 19, loss = 0.01483000
# Iteration 20, loss = 0.01201439
# Iteration 21, loss = 0.01024759
# Iteration 22, loss = 0.00842923
# Iteration 23, loss = 0.00721186
# Iteration 24, loss = 0.00610334
# Iteration 25, loss = 0.00532831
# Iteration 26, loss = 0.00467791
# Iteration 27, loss = 0.00406844
# Iteration 28, loss = 0.00355550
# Iteration 29, loss = 0.00312237
# Iteration 30, loss = 0.00283586
# Iteration 31, loss = 0.00252777
# Iteration 32, loss = 0.00230324
# Iteration 33, loss = 0.00205987
# Iteration 34, loss = 0.00188426
# Iteration 35, loss = 0.00174182
# Iteration 36, loss = 0.00158771
# Iteration 37, loss = 0.00146170
# Iteration 38, loss = 0.00138146
# Iteration 39, loss = 0.00127423
# Iteration 40, loss = 0.00119984
# Iteration 41, loss = 0.00111868
# Iteration 42, loss = 0.00104274
# Iteration 43, loss = 0.00098448
# Iteration 44, loss = 0.00092425
# Iteration 45, loss = 0.00087845
# Iteration 46, loss = 0.00082844
# Iteration 47, loss = 0.00078978
# Iteration 48, loss = 0.00075015
# Iteration 49, loss = 0.00071547
# Iteration 50, loss = 0.00068067
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.62023383
# Iteration 2, loss = 0.30510444
# Iteration 3, loss = 0.28233557
# Iteration 4, loss = 0.22898058
# Iteration 5, loss = 0.22401263
# Iteration 6, loss = 0.20725920
# Iteration 7, loss = 0.20153478
# Iteration 8, loss = 0.18796184
# Iteration 9, loss = 0.17755443
# Iteration 10, loss = 0.16858092
# Iteration 11, loss = 0.16048171
# Iteration 12, loss = 0.15145615
# Iteration 13, loss = 0.14441953
# Iteration 14, loss = 0.13536509
# Iteration 15, loss = 0.12708840
# Iteration 16, loss = 0.12313498
# Iteration 17, loss = 0.11944717
# Iteration 18, loss = 0.12039575
# Iteration 19, loss = 0.10844054
# Iteration 20, loss = 0.09637671
# Iteration 21, loss = 0.09474776
# Iteration 22, loss = 0.08397701
# Iteration 23, loss = 0.07631317
# Iteration 24, loss = 0.07296088
# Iteration 25, loss = 0.06710294
# Iteration 26, loss = 0.06267323
# Iteration 27, loss = 0.06228007
# Iteration 28, loss = 0.05270802
# Iteration 29, loss = 0.04823274
# Iteration 30, loss = 0.04383549
# Iteration 31, loss = 0.04276590
# Iteration 32, loss = 0.03799263
# Iteration 33, loss = 0.03344291
# Iteration 34, loss = 0.03219652
# Iteration 35, loss = 0.03307163
# Iteration 36, loss = 0.02562301
# Iteration 37, loss = 0.02454316
# Iteration 38, loss = 0.02072928
# Iteration 39, loss = 0.01908059
# Iteration 40, loss = 0.01828439
# Iteration 41, loss = 0.01547644
# Iteration 42, loss = 0.01367974
# Iteration 43, loss = 0.01247324
# Iteration 44, loss = 0.01132791
# Iteration 45, loss = 0.01033889
# Iteration 46, loss = 0.01020608
# Iteration 47, loss = 0.00873581
# Iteration 48, loss = 0.00787872
# Iteration 49, loss = 0.00733060
# Iteration 50, loss = 0.00651364
# Iteration 51, loss = 0.00608956
# Iteration 52, loss = 0.00558236
# Iteration 53, loss = 0.00512029
# Iteration 54, loss = 0.00480177
# Iteration 55, loss = 0.00463119
# Iteration 56, loss = 0.00440340
# Iteration 57, loss = 0.00428038
# Iteration 58, loss = 0.00396328
# Iteration 59, loss = 0.00357179
# Iteration 60, loss = 0.00326831
# Iteration 61, loss = 0.00304754
# Iteration 62, loss = 0.00299952
# Iteration 63, loss = 0.00268481
# Iteration 64, loss = 0.00251144
# Iteration 65, loss = 0.00240356
# Iteration 66, loss = 0.00226002
# Iteration 67, loss = 0.00217911
# Iteration 68, loss = 0.00206184
# Iteration 69, loss = 0.00196635
# Iteration 70, loss = 0.00193923
# Iteration 71, loss = 0.00195985
# Iteration 72, loss = 0.00186616
# Iteration 73, loss = 0.00179218
# Iteration 74, loss = 0.00165464
# Iteration 75, loss = 0.00160526
# Iteration 76, loss = 0.00148078
# Iteration 77, loss = 0.00143428
# Iteration 78, loss = 0.00136376
# Iteration 79, loss = 0.00130301
# Iteration 80, loss = 0.00126147
# Iteration 81, loss = 0.00120215
# Iteration 82, loss = 0.00117078
# Iteration 83, loss = 0.00113883
# Iteration 84, loss = 0.00107810
# Iteration 85, loss = 0.00111597
# Iteration 86, loss = 0.00114205
# Iteration 87, loss = 0.00103953
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.60236017
# Iteration 2, loss = 0.18961813
# Iteration 3, loss = 0.20435735
# Iteration 4, loss = 0.16102957
# Iteration 5, loss = 0.12811278
# Iteration 6, loss = 0.12011110
# Iteration 7, loss = 0.11030173
# Iteration 8, loss = 0.09555896
# Iteration 9, loss = 0.08714328
# Iteration 10, loss = 0.07417919
# Iteration 11, loss = 0.06596991
# Iteration 12, loss = 0.05909782
# Iteration 13, loss = 0.05253801
# Iteration 14, loss = 0.04679369
# Iteration 15, loss = 0.04171596
# Iteration 16, loss = 0.03613354
# Iteration 17, loss = 0.03291288
# Iteration 18, loss = 0.02735409
# Iteration 19, loss = 0.02357692
# Iteration 20, loss = 0.01981390
# Iteration 21, loss = 0.01688650
# Iteration 22, loss = 0.01434298
# Iteration 23, loss = 0.01236871
# Iteration 24, loss = 0.01007584
# Iteration 25, loss = 0.00829897
# Iteration 26, loss = 0.00709843
# Iteration 27, loss = 0.00618150
# Iteration 28, loss = 0.00521074
# Iteration 29, loss = 0.00452152
# Iteration 30, loss = 0.00394626
# Iteration 31, loss = 0.00346835
# Iteration 32, loss = 0.00290636
# Iteration 33, loss = 0.00273088
# Iteration 34, loss = 0.00234964
# Iteration 35, loss = 0.00212951
# Iteration 36, loss = 0.00192971
# Iteration 37, loss = 0.00177612
# Iteration 38, loss = 0.00163135
# Iteration 39, loss = 0.00150300
# Iteration 40, loss = 0.00139091
# Iteration 41, loss = 0.00129680
# Iteration 42, loss = 0.00121872
# Iteration 43, loss = 0.00113207
# Iteration 44, loss = 0.00106705
# Iteration 45, loss = 0.00099849
# Iteration 46, loss = 0.00093124
# Iteration 47, loss = 0.00088150
# Iteration 48, loss = 0.00083137
# Iteration 49, loss = 0.00078644
# Iteration 50, loss = 0.00074605
# Iteration 51, loss = 0.00071263
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.59054887
# Iteration 2, loss = 0.13134802
# Iteration 3, loss = 0.16437540
# Iteration 4, loss = 0.14422117
# Iteration 5, loss = 0.11041768
# Iteration 6, loss = 0.09503875
# Iteration 7, loss = 0.09233633
# Iteration 8, loss = 0.08563106
# Iteration 9, loss = 0.07521358
# Iteration 10, loss = 0.06990903
# Iteration 11, loss = 0.06313790
# Iteration 12, loss = 0.05614835
# Iteration 13, loss = 0.05115450
# Iteration 14, loss = 0.04542233
# Iteration 15, loss = 0.04067117
# Iteration 16, loss = 0.03493514
# Iteration 17, loss = 0.03131516
# Iteration 18, loss = 0.02761504
# Iteration 19, loss = 0.02271975
# Iteration 20, loss = 0.02000980
# Iteration 21, loss = 0.01659111
# Iteration 22, loss = 0.01346064
# Iteration 23, loss = 0.01140994
# Iteration 24, loss = 0.00943496
# Iteration 25, loss = 0.00777337
# Iteration 26, loss = 0.00638230
# Iteration 27, loss = 0.00530762
# Iteration 28, loss = 0.00449698
# Iteration 29, loss = 0.00374191
# Iteration 30, loss = 0.00328075
# Iteration 31, loss = 0.00281311
# Iteration 32, loss = 0.00249646
# Iteration 33, loss = 0.00225395
# Iteration 34, loss = 0.00195135
# Iteration 35, loss = 0.00175354
# Iteration 36, loss = 0.00162990
# Iteration 37, loss = 0.00143077
# Iteration 38, loss = 0.00134310
# Iteration 39, loss = 0.00121351
# Iteration 40, loss = 0.00112488
# Iteration 41, loss = 0.00103937
# Iteration 42, loss = 0.00097382
# Iteration 43, loss = 0.00090880
# Iteration 44, loss = 0.00084665
# Iteration 45, loss = 0.00079817
# Iteration 46, loss = 0.00075639
# Iteration 47, loss = 0.00071099
# Iteration 48, loss = 0.00068098
# Iteration 49, loss = 0.00064472
# Iteration 50, loss = 0.00061849
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.59610378
# Iteration 2, loss = 0.11511722
# Iteration 3, loss = 0.14572774
# Iteration 4, loss = 0.13892105
# Iteration 5, loss = 0.11414431
# Iteration 6, loss = 0.09496991
# Iteration 7, loss = 0.08964393
# Iteration 8, loss = 0.09154753
# Iteration 9, loss = 0.08776553
# Iteration 10, loss = 0.08326597
# Iteration 11, loss = 0.08249481
# Iteration 12, loss = 0.08117089
# Iteration 13, loss = 0.07739372
# Iteration 14, loss = 0.07485609
# Iteration 15, loss = 0.07305332
# Iteration 16, loss = 0.07006766
# Iteration 17, loss = 0.06788971
# Iteration 18, loss = 0.06517200
# Iteration 19, loss = 0.06151467
# Iteration 20, loss = 0.05898469
# Iteration 21, loss = 0.05622062
# Iteration 22, loss = 0.05262390
# Iteration 23, loss = 0.04920808
# Iteration 24, loss = 0.04751945
# Iteration 25, loss = 0.04221228
# Iteration 26, loss = 0.04072060
# Iteration 27, loss = 0.03797337
# Iteration 28, loss = 0.03308789
# Iteration 29, loss = 0.02975882
# Iteration 30, loss = 0.02661175
# Iteration 31, loss = 0.02299331
# Iteration 32, loss = 0.02108623
# Iteration 33, loss = 0.01835987
# Iteration 34, loss = 0.01625812
# Iteration 35, loss = 0.01365997
# Iteration 36, loss = 0.01199782
# Iteration 37, loss = 0.01053252
# Iteration 38, loss = 0.00890288
# Iteration 39, loss = 0.00789886
# Iteration 40, loss = 0.00692170
# Iteration 41, loss = 0.00649492
# Iteration 42, loss = 0.00569959
# Iteration 43, loss = 0.00496725
# Iteration 44, loss = 0.00429347
# Iteration 45, loss = 0.00399885
# Iteration 46, loss = 0.00349844
# Iteration 47, loss = 0.00321878
# Iteration 48, loss = 0.00291794
# Iteration 49, loss = 0.00250379
# Iteration 50, loss = 0.00245789
# Iteration 51, loss = 0.00210645
# Iteration 52, loss = 0.00200015
# Iteration 53, loss = 0.00181484
# Iteration 54, loss = 0.00167348
# Iteration 55, loss = 0.00161745
# Iteration 56, loss = 0.00159063
# Iteration 57, loss = 0.00152399
# Iteration 58, loss = 0.00131771
# Iteration 59, loss = 0.00123845
# Iteration 60, loss = 0.00118650
# Iteration 61, loss = 0.00117360
# Iteration 62, loss = 0.00108440
# Iteration 63, loss = 0.00106694
# Iteration 64, loss = 0.00098952
# Iteration 65, loss = 0.00089961
# Iteration 66, loss = 0.00088250
# Iteration 67, loss = 0.00083828
# Iteration 68, loss = 0.00078282
# Iteration 69, loss = 0.00077448
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.59310912
# Iteration 2, loss = 0.04300506
# Iteration 3, loss = 0.03443639
# Iteration 4, loss = 0.03758647
# Iteration 5, loss = 0.03799728
# Iteration 6, loss = 0.03592044
# Iteration 7, loss = 0.03318443
# Iteration 8, loss = 0.02801048
# Iteration 9, loss = 0.02299535
# Iteration 10, loss = 0.01928274
# Iteration 11, loss = 0.01668207
# Iteration 12, loss = 0.01519822
# Iteration 13, loss = 0.01252058
# Iteration 14, loss = 0.01118654
# Iteration 15, loss = 0.00979782
# Iteration 16, loss = 0.00882963
# Iteration 17, loss = 0.00782593
# Iteration 18, loss = 0.00694269
# Iteration 19, loss = 0.00623643
# Iteration 20, loss = 0.00564453
# Iteration 21, loss = 0.00499618
# Iteration 22, loss = 0.00461879
# Iteration 23, loss = 0.00417382
# Iteration 24, loss = 0.00382526
# Iteration 25, loss = 0.00350362
# Iteration 26, loss = 0.00330152
# Iteration 27, loss = 0.00306684
# Iteration 28, loss = 0.00286179
# Iteration 29, loss = 0.00270444
# Iteration 30, loss = 0.00253205
# Iteration 31, loss = 0.00242772
# Iteration 32, loss = 0.00225032
# Iteration 33, loss = 0.00211935
# Iteration 34, loss = 0.00201290
# Iteration 35, loss = 0.00188979
# Iteration 36, loss = 0.00176558
# Iteration 37, loss = 0.00169958
# Iteration 38, loss = 0.00155885
# Iteration 39, loss = 0.00146021
# Iteration 40, loss = 0.00136998
# Iteration 41, loss = 0.00128199
# Iteration 42, loss = 0.00120071
# Iteration 43, loss = 0.00110230
# Iteration 44, loss = 0.00103615
# Iteration 45, loss = 0.00096873
# Iteration 46, loss = 0.00088290
# Iteration 47, loss = 0.00082001
# Iteration 48, loss = 0.00075262
# Iteration 49, loss = 0.00069557
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
#               precision    recall  f1-score   support
#
#      papules       0.61      0.52      0.56        21
#   black_head       0.74      0.74      0.74        19
#   white_head       0.57      0.33      0.42        24
#    acne_scar       0.08      1.00      0.15         1
#      wrinkle       0.90      1.00      0.95        18
#       stains       1.00      0.73      0.84        11
#      freckle       0.87      0.87      0.87        15
#      nodules       0.40      0.33      0.36         6
#  dark_circle       0.92      0.69      0.79        16
#     pustules       0.00      0.00      0.00         7
#  skinredness       0.71      0.71      0.71         7
#     vascular       0.50      0.33      0.40         3
#    dark_spot       0.00      0.00      0.00         0
#      eye_bag       1.00      0.50      0.67         2
#
#    micro avg       0.68      0.62      0.65       150
#    macro avg       0.59      0.55      0.53       150
# weighted avg       0.71      0.62      0.65       150
#  samples avg       0.67      0.71      0.68       150

# %%
print(f"F1-macro: {f1_macro:.4f}")
# Out:
# F1-macro: 0.5330

# %%
print(classification_report(y_test, y_pred, target_names=classes, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#      papules       0.61      0.52      0.56        21
#   black_head       0.74      0.74      0.74        19
#   white_head       0.57      0.33      0.42        24
#    acne_scar       0.08      1.00      0.15         1
#      wrinkle       0.90      1.00      0.95        18
#       stains       1.00      0.73      0.84        11
#      freckle       0.87      0.87      0.87        15
#      nodules       0.40      0.33      0.36         6
#  dark_circle       0.92      0.69      0.79        16
#     pustules       0.00      0.00      0.00         7
#  skinredness       0.71      0.71      0.71         7
#     vascular       0.50      0.33      0.40         3
#    dark_spot       0.00      0.00      0.00         0
#      eye_bag       1.00      0.50      0.67         2
#
#    micro avg       0.68      0.62      0.65       150
#    macro avg       0.59      0.55      0.53       150
# weighted avg       0.71      0.62      0.65       150
#  samples avg       0.67      0.71      0.68       150

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import hamming_loss
from sklearn.metrics import average_precision_score

subset_acc = accuracy_score(y_test, y_pred)
print(f"Subset Accuracy: {subset_acc:.4f}")

hamming = hamming_loss(y_test, y_pred)
print(f"Hamming Loss: {hamming:.4f}")

map = average_precision_score(y_test, y_pred)
print(f"MAP: {map:.4f}")
# Out:
# Subset Accuracy: 0.5347
# Hamming Loss: 0.0714
# MAP: 0.4300
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(

# %%
joblib.dump(mlp_clf, f"{model_dir}/mlp_v1.pkl")
# Out:
# ['/content/drive/Shared drives/Desarrollo/models/mlp_v1.pkl']

# %% [markdown]
# # Pruebas modelos clasicos

# %%
from PIL import Image

simple_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

def preprocess_image_for_classical_model(image_path, scaler=None):
    image = Image.open(image_path).convert("RGB")
    image_tensor = simple_transform(image)
    image_array = image_tensor.numpy().reshape(-1)

    if scaler is not None:
        image_array = scaler.transform([image_array])[0]

    return image_array

# %%
def preprocess_image_for_classical_model(image_path):
    image = Image.open(image_path).convert('RGB')
    img_tensor = simple_transform(image).unsqueeze(0).to(device)
    with torch.no_grad():
        feats = feature_extractor(img_tensor)
    return feats.cpu().numpy().squeeze(0)

# %%
image_path = '/content/drive/Shared drives/Desarrollo/fotos de prueba/whac.jpg'

# %%
modelos=['mlp_v1.pkl', 'logistic_regression_v1.pkl', 'random_forest_v1.pkl', 'knn_v1.pkl', 'xgboost_v1.pkl']
for model_name in modelos:
  model_path = f"{model_dir}/{model_name}"
  model_loaded = joblib.load(model_path)
  x_new = preprocess_image_for_classical_model(image_path)
  y_pred = model_loaded.predict([x_new])[0]
  labels_predichas = [classes[i] for i, val in enumerate(y_pred) if val ==1]
  print("modelo", model_name)
  print("Predicciones:", labels_predichas)
  print("\n")
# Out:
# modelo mlp_v1.pkl
# Predicciones: ['papules', 'black_head', 'freckle']
#
#
# modelo logistic_regression_v1.pkl
# Predicciones: ['papules', 'freckle']
#
#
# modelo random_forest_v1.pkl
# Predicciones: []
#
#
# modelo knn_v1.pkl
# Predicciones: []
#
#
# modelo xgboost_v1.pkl
# Predicciones: ['freckle']
