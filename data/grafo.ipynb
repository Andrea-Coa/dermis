# %% [markdown]
# # Grafo de condiciones -> ingredientes -> productos

# %%
import json
import pandas as pd
import networkx as nx
import pickle

# %%
cleaned_products_csv_path = "cleaning/cleaned_products.csv"
ingredients_mappings_csv_path = "cleaning/ingredients_mappings.csv"
standardized_ingredients_fichas_csv_path = "cleaning/ingredientes_fichas_standardized.json"

# %%
products_df = pd.read_csv(cleaned_products_csv_path)
products_df.head(2)
# Out:
#                                                title      price  \
# 0  fotoprotector isdin fusión water pediatrics spf50  s/ 124.90
# 1  crema anti-irritación la roche posay lipikar 4...  s/ 176.90
#
#                                                 info  \
# 0  ['todo tipo de piel, incluso piel atópica y/o ...
# 1  ['calma la piel inmediatamente.', 'con su efic...
#
#                                          composition  \
# 0  vitamina e, provitamina b5, extracto de siempr...
# 1  aqua posae filiformis , microresyl: devuelve e...
#
#                                                usage  \
# 0  aplica fusion water magic pediatrics spf 50 ge...
# 1  aplicar sobre la piel limpia con masaje circul...
#
#                                          precautions           brand  \
# 0  uso externo. mantener el producto fuera del al...           isdin
# 1           mantener fuera del alcance de los niños.  la roche-posay
#
#                                                image  \
# 0  https://dcuk1cxrnzjkh.cloudfront.net/imagespro...
# 1  https://dcuk1cxrnzjkh.cloudfront.net/imagespro...
#
#                                          description  \
# 0  fotoprotector isdin fusión water pediatrics sp...
# 1  crema anti-irritación la roche posay lipikar b...
#
#                                                  url  limpiar  tratar  \
# 0  https://inkafarma.pe/producto/fotoprotector-is...    False   False
# 1  https://inkafarma.pe/producto/lipikar-baume-ap...    False    True
#
#    proteger                                   composition_list  \
# 0      True  ['vitamina e', 'provitamina b5', 'extracto de ...
# 1     False  ['aqua posae filiformis', 'microresyl', 'resta...
#
#                            composition_list_standard     id
# 0  ['tocoferol', 'extracto de siempreviva', 'vita...  P0000
# 1  ['manteca de karité', 'glicerina', 'niacinamid...  P0001

# %%
products_df["composition_list_standard"] = products_df.composition_list_standard.str.strip("[]").str.split(",").apply(lambda x: [i.strip().strip("'") for i in x])
products_df.head(2)
# Out:
#                                                title      price  \
# 0  fotoprotector isdin fusión water pediatrics spf50  s/ 124.90
# 1  crema anti-irritación la roche posay lipikar 4...  s/ 176.90
#
#                                                 info  \
# 0  ['todo tipo de piel, incluso piel atópica y/o ...
# 1  ['calma la piel inmediatamente.', 'con su efic...
#
#                                          composition  \
# 0  vitamina e, provitamina b5, extracto de siempr...
# 1  aqua posae filiformis , microresyl: devuelve e...
#
#                                                usage  \
# 0  aplica fusion water magic pediatrics spf 50 ge...
# 1  aplicar sobre la piel limpia con masaje circul...
#
#                                          precautions           brand  \
# 0  uso externo. mantener el producto fuera del al...           isdin
# 1           mantener fuera del alcance de los niños.  la roche-posay
#
#                                                image  \
# 0  https://dcuk1cxrnzjkh.cloudfront.net/imagespro...
# 1  https://dcuk1cxrnzjkh.cloudfront.net/imagespro...
#
#                                          description  \
# 0  fotoprotector isdin fusión water pediatrics sp...
# 1  crema anti-irritación la roche posay lipikar b...
#
#                                                  url  limpiar  tratar  \
# 0  https://inkafarma.pe/producto/fotoprotector-is...    False   False
# 1  https://inkafarma.pe/producto/lipikar-baume-ap...    False    True
#
#    proteger                                   composition_list  \
# 0      True  ['vitamina e', 'provitamina b5', 'extracto de ...
# 1     False  ['aqua posae filiformis', 'microresyl', 'resta...
#
#                            composition_list_standard     id
# 0  [tocoferol, extracto de siempreviva, vitamina b5]  P0000
# 1  [manteca de karité, glicerina, niacinamida, ag...  P0001

# %%
ingredients_df = pd.read_csv(ingredients_mappings_csv_path, encoding="utf-8", header=None, names=["name", "clean_name", "id"])
ingredients_df.head(2)
# Out:
#                       name               clean_name     id
# 0  extracto de siempreviva  extracto de siempreviva  I0000
# 1               microresyl               microresyl  I0001

# %%
with open(standardized_ingredients_fichas_csv_path, "r", encoding="utf-8") as f:
    ingredientes_fichas = json.load(f)
ingredientes_fichas[0:2]
# Out:
# [{'chemical': 'ácido cítrico',
#   'conditions': ['stains', 'dark_spot', 'skinredness']},
#  {'chemical': 'ácido glicólico',
#   'conditions': ['acne_scar',
#    'wrinkle',
#    'stains',
#    'dark_spot',
#    'white_head',
#    'papules']}]

# %%
# nodos del grafo
skin_conditions = ["stains", "dark_spot", "skinredness", "acne_scar",
                   "wrinkle", "papules", "white_head", "black_head",
                   "pustules", "nodules", "dark_circle", "eye_bag",
                   "vascular", "freckle"] # hyperkeratosis
ingredients = ingredients_df[ingredients_df.clean_name != "INVÁLIDO"].clean_name.unique().tolist()
products = products_df.title.unique().tolist()

# %%
ingredients_df[ingredients_df.clean_name == "INVÁLIDO"]
# Out:
#                                                   name clean_name     id
# 55                                             protege   INVÁLIDO  I0052
# 56                                  de amplio espectro   INVÁLIDO  I0052
# 57                                             cortos​   INVÁLIDO  I0052
# 60                                          con ph 5.5   INVÁLIDO  I0052
# 62                                              marcas   INVÁLIDO  I0052
# ..                                                 ...        ...    ...
# 774  oxido de hierro para reforzar la protección fr...   INVÁLIDO  I0052
# 775                          base limpiadora sin jabón   INVÁLIDO  I0052
# 776                           mejor conocidos como ahs   INVÁLIDO  I0052
# 777                     es apto para todo tipo de piel   INVÁLIDO  I0052
# 811                                           INVÁLIDO   INVÁLIDO  I0052
#
# [145 rows x 3 columns]

# %%
# Agregar los nodos al grafo
graph = nx.Graph()
graph.add_nodes_from(skin_conditions, type="skin_condition")
graph.add_nodes_from(ingredients, type="ingredient")
graph.add_nodes_from(products, type="product")

# %%
# Agregar aristas al grafo
# Primero de skin_conditions a ingredientes
for item in ingredientes_fichas:
    ing = item["chemical"]
    for cond in item["conditions"]:
        # Check if the condition node exists
        if cond not in graph:
            print(f"Warning: Node '{cond}' does not exist. Adding it as a 'skin_condition'.")
            graph.add_node(cond, type="skin_condition")
        
        # Check if the ingredient node exists
        if ing not in graph:
            print(f"Warning: Node '{ing}' does not exist. Adding it as an 'ingredient'.")
            graph.add_node(ing, type="ingredient")
        
        # Add the edge
        graph.add_edge(cond, ing, type="skin_condition_to_ingredient")
# Out:
# Warning: Node 'alfa tocoferol acetato' does not exist. Adding it as an 'ingredient'.
# Warning: Node 'ascorbil palmitato' does not exist. Adding it as an 'ingredient'.
# Warning: Node 'dexpantenol' does not exist. Adding it as an 'ingredient'.
# Warning: Node 'esencia limón' does not exist. Adding it as an 'ingredient'.

# %%
# Ahora de ingredientes a productos
for index, row in products_df.iterrows():
    product = row["title"]
    for ingredient in row["composition_list_standard"]:
        # Check if the ingredient node exists
        if ingredient == "": # a veces no hay ingredientes y la lista se vuelve [], resultando en un ingrediente vacío ""
            print(f"Warning: Empty ingredient in product '{product}'. Skipping this ingredient.")
            continue
        
        if ingredient not in graph:
            print(f"Warning: Node '{ingredient}' does not exist. Adding it as an 'ingredient'.")
            graph.add_node(ingredient, type="ingredient")
        
        # Check if the product node exists
        if product not in graph:
            print(f"Warning: Node '{product}' does not exist. Adding it as a 'product'.")
            graph.add_node(product, type="product")
        
        # Add the edge
        graph.add_edge(ingredient, product, type="ingredient_to_product")
# Out:
# Warning: Empty ingredient in product 'fotoprotector bioderma pediatrics  lait'. Skipping this ingredient.
# Warning: Empty ingredient in product 'loción hidratante cetaphil pro ac control 118ml'. Skipping this ingredient.
# Warning: Empty ingredient in product 'neotetrin 0.05% crema'. Skipping this ingredient.
# Warning: Empty ingredient in product 'fotoprotector photoderm bioderma spray'. Skipping this ingredient.

# %%
def get_products_for_condition(G, condition):
    products = set()
    for ingredient in G.neighbors(condition):
        print(f"Ingredient: {ingredient}")  # Print the ingredient
        for product in G.neighbors(ingredient):
            if G.nodes[product]["type"] == "product":
                products.add(product)
    return products

# %%
recommended_products = get_products_for_condition(graph, "stains")
for prod in recommended_products:
    row = products_df[products_df.title == prod]
    print(row["title"].values[0], ":", row["composition_list_standard"].values[0])
# Out:
# Ingredient: ácido cítrico
# Ingredient: ácido glicólico
# eucerin serum antimanchas dermopure triple effect 40ml : ['pantenol', 'glucosilrutina', 'almidón de tapioca', 'resorcinol amido tiazólico isobutilo', 'pantolactona', 'ácido cítrico', 'ácido salicílico', 'edta trisódico', 'glicerina', 'carbómero', 'agua', 'isoquercitrina', 'alcohol denaturado', 'extracto de raíz de glycyrrhiza inflata', 'fragancia', 'hidróxido de sodio', 'glicol decileno', 'copolímero de acrililo dimetiltaurato de amonio-VP']
# crema gel eucerin hyaluron filler ultra light : ['pantenol', 'hialuronato de sodio', 'escualano', 'pantolactona', 'alcohol denaturado', 'fenoxietanol', 'alcohol cetílico', 'ácido cítrico', 'hidroxihidrocinamato de pentaeritritilo tetra-di-t-butilo', 'carragenina', 'ácido láctico', 'tocoferol', 'goma de gellan', 'fosfato de distarch', 'lisina lauroil', 'alcohol behenílico', 'isononanoato de cetearyl', 'goma xantana', 'palmitato de isopropilo', 'glicerina', 'agua', 'fragancia']
# aceite de ducha eucerin ph5 400ml : ['pantenol', 'ácido araquídico', 'sulfosuccinato', 'cocoyl de sodio', 'alcohol ceteárico', 'almidón de tapioca', 'cloruro de sodio', 'ácido cítrico', 'ácido esteárico', 'fragancia', 'ácido palmítico', 'dióxido de titanio', 'isetionato', 'cocoamidopropil betaína', 'ácido oleico', 'lauril disódico', 'glicerina', 'octildodecanol', 'agua', 'ácido mirístico', 'citrato de sodio']
# serum isdinceutics retinal intense : ['tetrapéptido-7 palmitoil', 'capriloil glicol', 'óxido de estaño', 'copolímero de acrilato de sodio-2', 'alcohol denaturado', 'melatonina', 'triglicérido caprílico/cáprico', 'crisina', 'meticona peg/ppg-18/18 de laurilo', 'dimeticona', 'adipato de dibutilo', 'pentilenglicol', '4-t-butilciclohexanol', 'ácido cítrico', 'hidroxihidrocinamato de pentaeritritilo tetra-di-t-butilo', 'alcohol t-butilo', 'extracto de hoja de romero', 'bakuchiol', 'acetato de tocoferilo', 'maltodextrina', '2-hexanodiol', 'tocoferol', 'copolímero de poliacrilato-6', 'extracto de semilla de vigna aconitifolia', 'retinaldehído', 'dióxido de titanio', 'propanodiol', 'fosfolípidos', 'goma xantana', 'edta disódico', 'fluorfelogopita sintética', 'etilcelulosa', 'laurato de isoamilo', 'glicerina', 'niacinamida', 'ácido ascórbico', 'agua', 'sílice', 'fragancia', 'hidroxiacetofenona']
# crema corporal eucerin anti-pigment : ['pantenol', 'hialuronato de sodio', 'capriloil glicol', 'pantolactona', 'edta trisódico', 'alcohol denaturado', 'alcohol ceteárico', 'fenoxietanol', 'triglicérido caprílico/cáprico', 'cocoglicéridos', 'almidón de tapioca', 'ácido cítrico', 'ácido láctico', 'palmitato de cetilo', 'resorcinol amido tiazólico isobutilo', 'fosfato de distarch', 'triisostearina', 'alcohol behenílico', 'adipato de diisopropilo', 'goma xantana', 'manteca de karité', 'fosfato de almidón hidroxipropílico', 'glicerina', 'agua', 'citrato de estearato de glicerilo', 'fragancia']
# crema en gel hidratante cerave control de grasa : ['hialuronato de sodio', 'capriloil glicol', 'alcoholes c14-22', 'fenoxietanol', 'hidróxido de sodio', 'miristato de isopropilo', 'almidón de maíz', 'ácido cítrico', 'citrato de trietilo', 'carbómero', 'fitoesfingosina', 'copolímero de poliacrilato-6', 'alcohol cetearílico', 'alquil glucósido c12-20', 'isononanoato de cetearilo', 'goma xantana', 'metosulfato de behentrimonio', 'colesterol', 'ceramida', 'disuccinato de etilendiamina trisódico', 'glicerina', 'niacinamida', 'agua', 'sílice', 'ácido benzoico', 'lauroil lactilato de sodio']
# gel moussant bioderma actif sébium 200ml : ['ácido glicólico', 'gluconato de zinc', 'ácido salicílico']
# protector solar bioderma photoderm lait ultra fps50 : ['extracto de laminaria ochroleuca', 'ramnosa', 'capriloil glicol', 'sebacato de diisopropilo', 'bemotrizinol', 'benzoato de alquilo C12-15', 'goma de celulosa', 'hidróxido de sodio', 'triglicérido caprílico/cáprico', 'caprilato de propilheptilo', 'adipato de dibutilo', 'triazona de etilhexilo', 'copolímero de aceite de brassica campestris/aleurites fordii', 'ácido cítrico', '2-hexanodiol', 'tocoferol', 'ectoína', 'manitol', 'behenato de poliglicerilo-6', 'butamidotriazona dietilhexílica', 'propanodiol', 'carbonato de dicaprililo', 'alquilfosfato C20-22', 'goma xantana', 'estearato de poliglicerilo-6', 'xilitol', 'celulosa microcristalina', 'fructooligosacáridos', 'o-cimen-5-ol', 'glicerina', 'agua', 'avobenzona', 'alcoholes C20-22', 'citrato de sodio']
# glicolic 10% crema 60g : ['ácido glicólico', 'alfa-hidroxiácidos']
# serum pure vitamin c12 la roche-posay oil control - inkafarma : ['poliquaternium-67', 'hialuronato de sodio', 'pentilenglicol', 'laureth-23', 'capriloil glicol', 'ácido cítrico', 'ácido salicílico', 'disuccinato de etilendiamina trisódico', 'ácido ascórbico', 'glicerina', 'adenosina', 'hidróxido de potasio', 'fragancia', 'hidroxiacetofenona']
# fotoprotector isdin fusion water magic spf50 : ['ácido fenilbenzimidazol sulfónico', 'hialuronato de sodio', 'arginina', 'capriloil glicol', 'goma de esclerotio', 'sebato de diisopropilo', 'bemotrizinol', 'extracto de porphyridium cruentum', 'meticona peg/ppg-18/18 de laurilo', 'dimeticona', 'adipato de dibutilo', 'triazona de etilhexilo', 'pentilenglicol', 'ácido cítrico', 'salicilato de etilhexilo', 'polisorbato 60', 'acetato de tocoferilo', 'copolímero vp/eicoseno', 'sílice hidratada', 'propanodiol', 'goma xantana', 'diacetato de glutamato tetrasódico', 'glicerina', 'agua', 'sílice', 'avobenzona', 'fragancia', 'hidroxiacetofenona']
# sérum vichy normaderm probio bha : ['ácido glicólico', 'fracciones probióticas', 'agua', 'ácido salicílico']
# sérum voluminizador avène hyaluron activ b3 : ['hialuronato de sodio', 'pentilenglicol', 'ácido cítrico', 'benzoato de sodio', 'glicerina', 'niacinamida', 'adenosina', 'agua']
# gel limpiador espumoso facefact ceramide : ['tocoferol', 'hialuronato de sodio', 'cloruro de sodio', 'fenoxietanol', 'EDTA tetrasódico', 'capriloil glicol', 'ceramida', 'ácido cítrico', 'glicerina', 'niacinamida', 'agua', 'cocoamida DEA', 'clorfenesina', 'cocoamidopropil betaína', 'sulfato de lauril de sodio']
# protector solar anthelios uvmune fps 50+ infantil : ['ácido fenilbenzimidazol sulfónico', 'manteca de karité (Butyrospermum parkii)', 'sebato de diisopropilo', 'bemotrizinol', 'alcohol denaturado', 'benzoato de alquilo C12-15', 'miristato de isopropilo', 'triazona de etilhexilo', 'pentilenglicol', 'ácido cítrico', 'methoxypropylamino cyclohexenylideneethoxyethylcyanoacetate', 'tocoferol', 'copolímero de acrilato de alquilo C12-22/hidroxiacrilato de etilo', 'copolímero de acrilatos/c10-30 alquil acrilato', 'propanodiol', 'palmitato de isopropilo', 'drometrizoltrisiloxano', 'éter de dicaprililo', 'glicerina', 'avobenzona', 'hidroxiacetofenona']
# gel concentrado eucerin dermopure triple effect : ['laureth sulfato de sodio', 'gluconolactona', 'coco-glucósido', 'peg-8', 'ácido cítrico', 'ácido salicílico', 'disuccinato de etilendiamina trisódico', 'glicerina', 'ácido glicólico', 'agua', 'alcohol denaturado', 'fragancia', 'fenoxietanol', 'hidróxido de sodio', 'goma xantana']
# sérum b3 vichy liftactiv antimanchas y arrugas : ['ácido glicólico', 'niacinamida', 'vitamina c', 'péptidos procolágeno']
# limpiador control imperfecciones cerave 236 ml : ['ácido glicólico', 'ceramida', 'ácido láctico']
# fotoprotector invisible stick isdin 50 spf - inkafarma : ['pantenol', 'cera de candelilla', 'bemotrizinol', 'alcohol ceteárico', 'adipato de dibutilo', 'triazona de etilhexilo', 'cocoglicéridos', 'ácido cítrico', 'acetato de tocoferilo', 'esteroles de brassica campestris', 'tocoferol', 'avobenzona', 'carbonato de dicaprililo', 'aceite de ricino hidrogenado', 'manteca de karité', 'extracto de semilla de girasol', 'hexil benzoato de diethylamino hidroxybenzoyl', 'sílice', 'cera de salvado de arroz', 'extracto de phaeodactylum tricornutum']
# bálsamo para piel sensible eucerin da control - inkafarma : ['capriloil glicol', 'PCA de sodio', 'edta trisódico', 'alcohol ceteárico', 'fenoxietanol', 'hidróxido de sodio', 'triglicérido caprílico/cáprico', 'ácido cítrico', 'carbómero', 'clorhidrato de arginina', 'palmitato de ascorbilo', 'tocoferol', 'glicina', 'fosfato de distarch', 'sulfato de ceteárico de sodio', 'extracto de raíz de glycyrrhiza inflata', 'aceite de semilla de vitis vinifera', 'aceite de onagra', 'manteca de karité', 'ceramida', 'benzoato de sodio', 'glicerina', 'octildodecanol', 'agua', 'estearato de glicerilo SE', 'citrato de sodio']
# la roche posay sérum effaclar anti-imperfecciones 30ml : ['ácido lipohidroxi', 'ácido salicílico', 'ácido glicólico', 'niacinamida', 'agua']
# gel limpiador facial eucerin anti-pigment - inkafarma : ['cloruro de sodio', 'benzoato de sodio', 'ácido láctico', 'glicerina', 'ácido glicólico', 'coco-betaína', 'agua', 'glucósido de glicerilo', 'hidróxido de sodio', 'goma xantana', 'cocoamfoacetato de sodio']
# serum vitamina c fisserum complejo b, e y ferulic : ['tocoferol', 'pantenol', 'hialuronato de sodio', 'laureth-23', 'ácido cítrico', 'ácido ferúlico', 'PCA de sodio', 'etoxidiglicol', 'ácido ascórbico', 'glicerina', 'niacinamida', 'agua', 'fenoxietanol', 'trietanolamina', 'propilenglicol']
# gel limpiador concentrado eucerin dermopure : ['laureth sulfato de sodio', 'gluconolactona', 'coco-glucósido', 'peg-8', 'ácido cítrico', 'ácido salicílico', 'disuccinato de etilendiamina trisódico', 'glicerina', 'ácido glicólico', 'agua', 'alcohol denaturado', 'fragancia', 'fenoxietanol', 'hidróxido de sodio', 'goma xantana']
# contorno de ojos eucerin antipigment : ['óxido de hierro negro', 'hialuronato de sodio', 'estearato de glicerilo', 'edta trisódico', 'alcohol denaturado', 'alcohol ceteárico', 'hidróxido de sodio', 'triglicérido caprílico/cáprico', 'cocoglicéridos', 'cloruro de sodio', 'ácido cítrico', 'palmitato de cetilo', 'óxido de hierro rojo', 'resorcinol amido tiazólico isobutilo', 'óxido de hierro amarillo', 'lisina lauroil', 'dióxido de titanio', 'extracto de raíz de glycyrrhiza inflata', 'goma xantana', 'palmitato de isopropilo', 'extracto de fruto de pimpinella anisum', 'manteca de karité', 'estearoil glutamato de sodio', 'glicerina', 'agua']
# sérum antimanchas l'oréal paris glycolic bright : ['ácido glicólico']

# %%
with open("skincare_graph.pkl", "wb") as f:
    pickle.dump(graph, f)

# %%
# Contar el grado de los nodos de tipo "skin_condition"
skin_condition_degrees = {node: graph.degree(node) for node in graph.nodes if graph.nodes[node].get('type') == 'skin_condition'}

# Mostrar los grados
for condition, degree in skin_condition_degrees.items():
    print(f"Condición: {condition}, Grado: {degree}")
# Out:
# Condición: stains, Grado: 2
# Condición: dark_spot, Grado: 7
# Condición: skinredness, Grado: 11
# Condición: acne_scar, Grado: 5
# Condición: wrinkle, Grado: 8
# Condición: papules, Grado: 7
# Condición: white_head, Grado: 4
# Condición: black_head, Grado: 1
# Condición: pustules, Grado: 1
# Condición: nodules, Grado: 1
# Condición: dark_circle, Grado: 1
# Condición: eye_bag, Grado: 1
# Condición: vascular, Grado: 1
# Condición: freckle, Grado: 0
